# %%
import os
from dotenv import load_dotenv

# %load_ext dotenv
# %dotenv

#環境変数として読み出し
CONSUMER_KEY = os.getenv('CONSUMER_KEY')
CONSUMER_SECRET = os.getenv('CONSUMER_SECRET')
ACCESS_TOKEN = os.getenv('ACCESS_TOKEN')
ACCESS_SECRET = os.getenv('ACCESS_SECRET')

# %%
from pyzaim import ZaimAPI

def getZaimData():
    """Zaimのデータを取得する
    """

    consumer_key = CONSUMER_KEY
    consumer_secret = CONSUMER_SECRET
    access_token = ACCESS_TOKEN
    access_secret = ACCESS_SECRET

    api = ZaimAPI(consumer_key, consumer_secret,
                  access_token, access_secret, 'verifier')
    # データ一覧の取得
    datas = api.get_data()

    # カテゴリ一覧情報
    categories = api.category_itos

    # ジャンル一覧情報を取得
    genres = api.genre_itos

    # 口座一覧情報を取得
    accounts = api.account_itos

    msg = str(len(datas)) + " 件のデータを取得しました"
    print(msg)

    return [datas, categories, genres, accounts]

# %%
datas, categories, genres, accounts = getZaimData()
len(datas)
# Out:
# 2839 件のデータを取得しました
# 2839

# %%
def convertData(datas, categories, genres, accounts):
    """IDをもとに名称を付与する
    """

    for data in datas:

        # カテゴリ名を付与
        categoryId = int(data["category_id"])
        data["category"] = categories[categoryId] if categoryId > 0 else ""

        # 内訳名を付与
        genreId = int(data["genre_id"])
        data["genre"] = genres[genreId] if genreId > 0 else ""

        # 口座名を付与
        fromAccountId = int(data["from_account_id"])
        data["from"] = accounts[fromAccountId] if fromAccountId > 0 else "-"

        toAccountId = int(data["to_account_id"])
        data["to"] = accounts[toAccountId] if toAccountId > 0 else "-"

    return datas
import csv

def outputCSV(datas):
    """カラム名を日本語に置換し、CSV出力する
    """

    # 種別名を日本語に置換
    for data in datas:
        keys = {
            "date": "日付",
            "receipt_id": "レシートID",
            "category_id" : "カテゴリID",
            "category": "カテゴリ",
            "genre_id": "ジャンルID",
            "genre": "ジャンル",
            "name": "商品名",
            "place": "お店",
            "mode": "方法",
            "from": "支払元",
            "to": "入金先",
            "currency_code": "通貨",
            "category_id",
            
            "comment": "メモ"
        }
        for k, v in keys.items():
            data[v] = data.pop(k)

        # 入出金
        data["収入"] = data.pop("amount") if data["方法"] == "income" else 0
        data["支出"] = data.pop("amount") if data["方法"] == "payment" else 0
        data["振替"] = data.pop("amount") if data["方法"] == "transfer" else 0

        # 不要なキーを削除
        unUsedKeys = ["id", "user_id", "from_account_id", "to_account_id", "active", "created", "place_uid", "original_money_ids"]
        for key in unUsedKeys:
            if(key in data):
                data.pop(key)

    # ヘッダーを指定
    fieldName = list(keys.values())
    fieldName.extend(['収入', '支出', '振替'])

    # CSV出力
    with open('../csv/zaim.csv', 'w', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldName)
        writer.writeheader()
        writer.writerows(datas)

# %%
# 種別名を付与する
datas = convertData(datas, categories, genres, accounts)
# CSV出力
outputCSV(datas)

# %%
datas = convertData(datas, categories, genres, accounts)
datas
# Out:
# [{'id': 6731369490,
#   'user_id': 8264209,
#   'date': '2023-03-24',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 54,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 21:09:32',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1679659743,
#   'place_uid': 'yh-blH7x9TCaos',
#   'place': '西友\u3000国立店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6731369479,
#   'user_id': 8264209,
#   'date': '2023-03-24',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 295,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 21:09:31',
#   'currency_code': 'JPY',
#   'name': 'KKトイレットS',
#   'receipt_id': 1679659743,
#   'place_uid': 'yh-blH7x9TCaos',
#   'place': '西友\u3000国立店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6731369467,
#   'user_id': 8264209,
#   'date': '2023-03-24',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 248,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 21:09:31',
#   'currency_code': 'JPY',
#   'name': 'ソフトパックティッシュ',
#   'receipt_id': 1679659743,
#   'place_uid': 'yh-blH7x9TCaos',
#   'place': '西友\u3000国立店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6729975720,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 11,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:57',
#   'currency_code': 'JPY',
#   'name': '釧圏BI',
#   'receipt_id': 1679622101,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729975714,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 42,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:57',
#   'currency_code': 'JPY',
#   'name': '小II',
#   'receipt_id': 1679622101,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729975708,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 23,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:57',
#   'currency_code': 'JPY',
#   'name': 'タ884M1棄鎮きそぱ',
#   'receipt_id': 1679622101,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729975702,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 78,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:56',
#   'currency_code': 'JPY',
#   'name': 'タ8hNハチ荒挽こしょう',
#   'receipt_id': 1679622101,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729974931,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 57,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:33',
#   'currency_code': 'JPY',
#   'name': '不明',
#   'receipt_id': 1679622069,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729974926,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 159,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:32',
#   'currency_code': 'JPY',
#   'name': 'キャベツ',
#   'receipt_id': 1679622069,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729974922,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 399,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:32',
#   'currency_code': 'JPY',
#   'name': 'スカイリーフカラダオモイノコメアブラ',
#   'receipt_id': 1679622069,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6729974911,
#   'user_id': 8264209,
#   'date': '2023-03-22',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 159,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-24 10:41:32',
#   'currency_code': 'JPY',
#   'name': 'スプーンジョウハクトウ',
#   'receipt_id': 1679622069,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6721060655,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 71,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:25:45',
#   'currency_code': 'JPY',
#   'name': '不明',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6721057017,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 105,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:27',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721057007,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 190,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:27',
#   'currency_code': 'JPY',
#   'name': 'ブルガリアフローズンヨーグル',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056993,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 55,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:27',
#   'currency_code': 'JPY',
#   'name': 'ブラック',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056985,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 55,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:26',
#   'currency_code': 'JPY',
#   'name': '復刻3色トリノ',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056973,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 79,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:26',
#   'currency_code': 'JPY',
#   'name': '爽練乳いちご',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056944,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 158,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:26',
#   'currency_code': 'JPY',
#   'name': '爽メロンソーダフロート',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056934,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 79,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:25',
#   'currency_code': 'JPY',
#   'name': '爽10年目のバニラ',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056929,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 98,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:25',
#   'currency_code': 'JPY',
#   'name': 'アサヒ贅沢搾り桃3',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056921,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 98,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:25',
#   'currency_code': 'JPY',
#   'name': 'アサヒ贅沢搾りグレー',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056914,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 128,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:24',
#   'currency_code': 'JPY',
#   'name': 'ブルガリアヨーグルトLB',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056904,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 105,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:24',
#   'currency_code': 'JPY',
#   'name': 'トモヱ乳業北海道プレー',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056896,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 98,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:24',
#   'currency_code': 'JPY',
#   'name': 'ウィルフィリピン産バナ',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6721056882,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 138,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 19:24:23',
#   'currency_code': 'JPY',
#   'name': '越後製菓ふんわり名人き',
#   'receipt_id': 1679307847,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6720058321,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -330,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:58',
#   'currency_code': 'JPY',
#   'name': '大介払い',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058288,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 44,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:58',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058279,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -15,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:58',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058267,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -71,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:57',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058256,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 161,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:57',
#   'currency_code': 'JPY',
#   'name': 'ニッシンナマパスタタラコトウニ',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058232,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 152,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:57',
#   'currency_code': 'JPY',
#   'name': 'ニッシンチュウカシルナシタンタンメン',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6720058220,
#   'user_id': 8264209,
#   'date': '2023-03-20',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 258,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-20 12:42:57',
#   'currency_code': 'JPY',
#   'name': 'イセアカドリノウマミサンラン10コ',
#   'receipt_id': 1679283756,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6707173654,
#   'user_id': 8264209,
#   'date': '2023-03-15',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 30,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-15 12:37:00',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678851407,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6707173647,
#   'user_id': 8264209,
#   'date': '2023-03-15',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 100,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-15 12:37:00',
#   'currency_code': 'JPY',
#   'name': 'チャック付マスクポーチ',
#   'receipt_id': 1678851407,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6707173632,
#   'user_id': 8264209,
#   'date': '2023-03-15',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 100,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-15 12:36:59',
#   'currency_code': 'JPY',
#   'name': 'キレイストッカースモール',
#   'receipt_id': 1678851407,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6707173607,
#   'user_id': 8264209,
#   'date': '2023-03-15',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 100,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-15 12:36:59',
#   'currency_code': 'JPY',
#   'name': 'シャカシャカねぎポット',
#   'receipt_id': 1678851407,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704783393,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 111,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:05',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704783386,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 721,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:05',
#   'currency_code': 'JPY',
#   'name': 'コクサンワカドリムネニク1マイ',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704783375,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 159,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:05',
#   'currency_code': 'JPY',
#   'name': 'ヒトカブマイタケ',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704783364,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 159,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:05',
#   'currency_code': 'JPY',
#   'name': 'キャベツ',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704783349,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 178,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:04',
#   'currency_code': 'JPY',
#   'name': 'ロッテソウメロンソーダ',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704783334,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 178,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 12:13:04',
#   'currency_code': 'JPY',
#   'name': 'メイジエッセルスーパーカップマッチャ',
#   'receipt_id': 1678763570,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6704646707,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 53,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:57',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704646676,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 23,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:56',
#   'currency_code': 'JPY',
#   'name': '1食焼きそば',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704646632,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 84,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:56',
#   'currency_code': 'JPY',
#   'name': '緑の小籾納豆',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704646588,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 188,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:55',
#   'currency_code': 'JPY',
#   'name': '白菜キムチ40',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704646561,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 170,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:54',
#   'currency_code': 'JPY',
#   'name': '肉だんご',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6704646544,
#   'user_id': 8264209,
#   'date': '2023-03-14',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 198,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-14 11:05:54',
#   'currency_code': 'JPY',
#   'name': '冷凍バラ',
#   'receipt_id': 1678759542,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6700274361,
#   'user_id': 8264209,
#   'date': '2023-03-12',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 11,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-12 17:50:29',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678611012,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6700274342,
#   'user_id': 8264209,
#   'date': '2023-03-12',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 148,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-12 17:50:29',
#   'currency_code': 'JPY',
#   'name': 'o森永あじわい便り1000',
#   'receipt_id': 1678611012,
#   'place_uid': 'yh-tSyrJPHRQIc',
#   'place': 'クリエイトＳ・Ｄ府中武蔵台店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6700272579,
#   'user_id': 8264209,
#   'date': '2023-03-12',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 110,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-12 17:50:02',
#   'currency_code': 'JPY',
#   'name': 'ゴミ袋',
#   'receipt_id': 1678610977,
#   'place_uid': 'zm-9088f80ff7a64735',
#   'place': 'ダイソー',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6698254680,
#   'user_id': 8264209,
#   'date': '2023-03-12',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 1982,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-12 06:13:39',
#   'currency_code': 'JPY',
#   'name': '蛍光灯',
#   'receipt_id': 1678569197,
#   'place_uid': 'zm-b3b3a6ac74ecbd56',
#   'place': 'Amazon',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6696395846,
#   'user_id': 8264209,
#   'date': '2023-03-11',
#   'mode': 'payment',
#   'category_id': 106,
#   'genre_id': 10604,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 1760,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-11 14:11:57',
#   'currency_code': 'JPY',
#   'name': '設置・運搬費料',
#   'receipt_id': 1678511429,
#   'place_uid': '',
#   'place': '',
#   'category': '住まい',
#   'genre': '家電',
#   'from': '-',
#   'to': '-'},
#  {'id': 6696395840,
#   'user_id': 8264209,
#   'date': '2023-03-11',
#   'mode': 'payment',
#   'category_id': 106,
#   'genre_id': 10604,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 3740,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-11 14:11:57',
#   'currency_code': 'JPY',
#   'name': 'リサイクル料金',
#   'receipt_id': 1678511429,
#   'place_uid': '',
#   'place': '',
#   'category': '住まい',
#   'genre': '家電',
#   'from': '-',
#   'to': '-'},
#  {'id': 6696395832,
#   'user_id': 8264209,
#   'date': '2023-03-11',
#   'mode': 'payment',
#   'category_id': 106,
#   'genre_id': 10604,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 33200,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-11 14:11:57',
#   'currency_code': 'JPY',
#   'name': '冷蔵庫',
#   'receipt_id': 1678511429,
#   'place_uid': '',
#   'place': '',
#   'category': '住まい',
#   'genre': '家電',
#   'from': '-',
#   'to': '-'},
#  {'id': 6694604538,
#   'user_id': 8264209,
#   'date': '2023-03-10',
#   'mode': 'payment',
#   'category_id': 105,
#   'genre_id': 10501,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 3333,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-10 19:05:49',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 0,
#   'place_uid': '',
#   'place': '',
#   'category': '水道・光熱',
#   'genre': '水道料金',
#   'from': '-',
#   'to': '-'},
#  {'id': 6694541980,
#   'user_id': 8264209,
#   'date': '2023-03-10',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': -33,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-10 18:39:19',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1678441141,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6694541968,
#   'user_id': 8264209,
#   'date': '2023-03-10',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 217,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-10 18:39:19',
#   'currency_code': 'JPY',
#   'name': 'パヌノフレゆず',
#   'receipt_id': 1678441141,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691520301,
#   'user_id': 8264209,
#   'date': '2023-03-09',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 25,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:48:16',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678333677,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691520289,
#   'user_id': 8264209,
#   'date': '2023-03-09',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -8,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:48:16',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1678333677,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691520280,
#   'user_id': 8264209,
#   'date': '2023-03-09',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 234,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:48:16',
#   'currency_code': 'JPY',
#   'name': 'Fイセアカドリノウマミサンラン10コ',
#   'receipt_id': 1678333677,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691520263,
#   'user_id': 8264209,
#   'date': '2023-03-09',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 90,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:48:16',
#   'currency_code': 'JPY',
#   'name': 'Fソウレンニュウイチゴ',
#   'receipt_id': 1678333677,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691526073,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 67,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:46',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691526061,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 23,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:46',
#   'currency_code': 'JPY',
#   'name': 'ゝヽ1食焼きそば',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691526054,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 84,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:45',
#   'currency_code': 'JPY',
#   'name': '緑の小粒納豆',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691526038,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 238,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:45',
#   'currency_code': 'JPY',
#   'name': '豆板醤',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691526030,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 328,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:45',
#   'currency_code': 'JPY',
#   'name': 'コンソメ',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691526020,
#   'user_id': 8264209,
#   'date': '2023-03-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 168,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:45',
#   'currency_code': 'JPY',
#   'name': '、、・、つゆの索',
#   'receipt_id': 1678333834,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6691525091,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 35,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:19',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691525080,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -200,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:19',
#   'currency_code': 'JPY',
#   'name': '大介支払い',
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691525047,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 89,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:18',
#   'currency_code': 'JPY',
#   'name': 'ノ料',
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691525032,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 78,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:18',
#   'currency_code': 'JPY',
#   'name': 'ヤサシイミズノ諦桝ン',
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691525021,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 110,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:17',
#   'currency_code': 'JPY',
#   'name': 'テンネンスイピュアノモリ',
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6691525008,
#   'user_id': 8264209,
#   'date': '2023-03-06',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 139,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-09 12:50:17',
#   'currency_code': 'JPY',
#   'name': "サッホ'Dチョウォ\\1ウメサリー",
#   'receipt_id': 1678333726,
#   'place_uid': '',
#   'place': '',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6681892385,
#   'user_id': 8264209,
#   'date': '2023-03-05',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 1091,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-05 16:43:50',
#   'currency_code': 'JPY',
#   'name': 'フライパン',
#   'receipt_id': 1678002217,
#   'place_uid': 'zm-b3b3a6ac74ecbd56',
#   'place': 'Amazon',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6681769823,
#   'user_id': 8264209,
#   'date': '2023-03-05',
#   'mode': 'payment',
#   'category_id': 105,
#   'genre_id': 10503,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 5279,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-05 16:13:38',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 1678000390,
#   'place_uid': 'zm-4e9c08c833ab8f16',
#   'place': 'エナジーダイレクト',
#   'category': '水道・光熱',
#   'genre': 'ガス料金',
#   'from': '-',
#   'to': '-'},
#  {'id': 6681767117,
#   'user_id': 8264209,
#   'date': '2023-03-05',
#   'mode': 'payment',
#   'category_id': 105,
#   'genre_id': 10503,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 6257,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-05 16:13:00',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 1678000341,
#   'place_uid': 'zm-4e9c08c833ab8f16',
#   'place': 'エナジーダイレクト',
#   'category': '水道・光熱',
#   'genre': 'ガス料金',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639286,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': -8995,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:44',
#   'currency_code': 'JPY',
#   'name': '不明',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639269,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 115,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:44',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639260,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 78,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:44',
#   'currency_code': 'JPY',
#   'name': 'にんにく中国産',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639233,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 65,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:43',
#   'currency_code': 'JPY',
#   'name': 'ドラムスティック',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639206,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 2,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:43',
#   'currency_code': 'JPY',
#   'name': '鶏モモ肉',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639182,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 228,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:43',
#   'currency_code': 'JPY',
#   'name': '銅名むぎ枝豆',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639166,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 198,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:42',
#   'currency_code': 'JPY',
#   'name': '畑金の鶏だし',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678639142,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 9873,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:42',
#   'currency_code': 'JPY',
#   'name': '00so04楕算機4',
#   'receipt_id': 1677914494,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6678638255,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 382,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:29',
#   'currency_code': 'JPY',
#   'name': '不明',
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638243,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 48,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:29',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638228,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 15,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:29',
#   'currency_code': 'JPY',
#   'name': '1カブマイタケ',
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638221,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 82,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:29',
#   'currency_code': 'JPY',
#   'name': "タ8メイジェッ!ルスーポーカッフ'ティラえス",
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638202,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 2,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:28',
#   'currency_code': 'JPY',
#   'name': "タ8メイジエッ14ルスーバーカツフ'マッチャve",
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638193,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 129,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:28',
#   'currency_code': 'JPY',
#   'name': 'タ・8タクVイッヒンタイメ2ワ21',
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6678638182,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 1,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 16:21:28',
#   'currency_code': 'JPY',
#   'name': 'ク86日0WAホッtケ*4トツクス',
#   'receipt_id': 1677914471,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6677633620,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 10,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 10:54:52',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1677894871,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6677633611,
#   'user_id': 8264209,
#   'date': '2023-03-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 100,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-04 10:54:52',
#   'currency_code': 'JPY',
#   'name': 'コーナークッションNベーシックカラー2',
#   'receipt_id': 1677894871,
#   'place_uid': '',
#   'place': '',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6676393135,
#   'user_id': 8264209,
#   'date': '2023-03-03',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 26,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-03 18:39:12',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1677836342,
#   'place_uid': 'yh-CG565VsDF0U',
#   'place': '西友\u3000国分寺食品館',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6676393122,
#   'user_id': 8264209,
#   'date': '2023-03-03',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 158,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-03 18:39:12',
#   'currency_code': 'JPY',
#   'name': 'KKアルミホイル',
#   'receipt_id': 1677836342,
#   'place_uid': 'yh-CG565VsDF0U',
#   'place': '西友\u3000国分寺食品館',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6676393106,
#   'user_id': 8264209,
#   'date': '2023-03-03',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 108,
#   'comment': '',
#   'active': 1,
#   'created': '2023-03-03 18:39:11',
#   'currency_code': 'JPY',
#   'name': 'KKラップ22x50',
#   'receipt_id': 1677836342,
#   'place_uid': 'yh-CG565VsDF0U',
#   'place': '西友\u3000国分寺食品館',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 6655951284,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -800,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:21',
#   'currency_code': 'JPY',
#   'name': '大介支払い',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951271,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 129,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:20',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951253,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 139,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:20',
#   'currency_code': 'JPY',
#   'name': 'アボカド(バラ)',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951239,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 159,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:20',
#   'currency_code': 'JPY',
#   'name': 'JA4バラギレタス',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951222,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 199,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:20',
#   'currency_code': 'JPY',
#   'name': 'キャベツ',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951202,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 379,
#   'comment': '',
#   'active': 1,
#   'created': '2023-02-24 12:39:19',
#   'currency_code': 'JPY',
#   'name': 'タネ8オオサカオウショウプルモチスイギョウサ',
#   'receipt_id': 1677209932,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 6655951177,
#   'user_id': 8264209,
#   'date': '2023-02-24',
#   'mode': 'payment',
#   'category_id': 101,
# ...
#   'date': '2022-06-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 77,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-10 18:59:26',
#   'currency_code': 'JPY',
#   'name': 'エッセルスーパーカップカフェオレクッキー20',
#   'receipt_id': 1654855141,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5987820501,
#   'user_id': 8264209,
#   'date': '2022-06-07',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 140,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-10 18:59:24',
#   'currency_code': 'JPY',
#   'name': 'タ4Bガリガリクンスモモ105mi',
#   'receipt_id': 1654855141,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5977786729,
#   'user_id': 8264209,
#   'date': '2022-06-06',
#   'mode': 'payment',
#   'category_id': 110,
#   'genre_id': 11002,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 1200,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-06 12:36:05',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 0,
#   'place_uid': 'zm-5da51a75d3b89250',
#   'place': 'ヨドバシドットコム',
#   'category': '医療・保険',
#   'genre': '薬代',
#   'from': '-',
#   'to': '-'},
#  {'id': 5979978385,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -150,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-07 11:10:52',
#   'currency_code': 'JPY',
#   'name': '大介支払い',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5979978343,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 33,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-07 11:10:50',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5974493278,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': -11,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-05 12:39:01',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5974493209,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 125,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-05 12:39:00',
#   'currency_code': 'JPY',
#   'name': 'アジノモト50g',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5974493142,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 169,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-05 12:38:59',
#   'currency_code': 'JPY',
#   'name': 'Kカコウバレイショデンプン500g',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5974492996,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 140,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-05 12:38:57',
#   'currency_code': 'JPY',
#   'name': 'ニッシンシルナシタンタンメンオオモリ',
#   'receipt_id': 1654400308,
#   'place_uid': 'yh-JbNIMN0r0wM',
#   'place': 'オーケー\u3000西国分寺店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5974233925,
#   'user_id': 8264209,
#   'date': '2022-06-05',
#   'mode': 'payment',
#   'category_id': 105,
#   'genre_id': 10503,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 3086,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-05 11:21:01',
#   'currency_code': 'JPY',
#   'name': '',
#   'receipt_id': 1654395640,
#   'place_uid': 'zm-4e9c08c833ab8f16',
#   'place': 'エナジーダイレクト',
#   'category': '水道・光熱',
#   'genre': 'ガス料金',
#   'from': '-',
#   'to': '-'},
#  {'id': 5972922512,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 140,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 20:15:51',
#   'currency_code': 'JPY',
#   'name': 'クリニカFMタテ型',
#   'receipt_id': 1654341336,
#   'place_uid': 'yh-AXCqxJsDmx2',
#   'place': '株式会社サンドラッグ\u3000国分寺本町店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5972922468,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 217,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 20:15:50',
#   'currency_code': 'JPY',
#   'name': 'アジエンスしっとりCD替',
#   'receipt_id': 1654341336,
#   'place_uid': 'yh-AXCqxJsDmx2',
#   'place': '株式会社サンドラッグ\u3000国分寺本町店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5972922432,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': -33,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 20:15:49',
#   'currency_code': 'JPY',
#   'name': '割引',
#   'receipt_id': 1654341336,
#   'place_uid': 'yh-AXCqxJsDmx2',
#   'place': '株式会社サンドラッグ\u3000国分寺本町店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5972922378,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 102,
#   'genre_id': 10201,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 217,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 20:15:48',
#   'currency_code': 'JPY',
#   'name': 'アジエンスしっとりSP替',
#   'receipt_id': 1654341336,
#   'place_uid': 'yh-AXCqxJsDmx2',
#   'place': '株式会社サンドラッグ\u3000国分寺本町店',
#   'category': '日用雑貨',
#   'genre': '消耗品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971887991,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 43,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:51:24',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971887928,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 88,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:51:23',
#   'currency_code': 'JPY',
#   'name': '木村ポキッコカフェオ',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971879946,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 88,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:49:18',
#   'currency_code': 'JPY',
#   'name': '木村ポキッコミックス',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971879828,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 28,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:49:16',
#   'currency_code': 'JPY',
#   'name': '濃厚豆乳絹ごし',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971879764,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 40,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:49:15',
#   'currency_code': 'JPY',
#   'name': '1食蕎麦',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971879670,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 168,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:49:14',
#   'currency_code': 'JPY',
#   'name': '白菜キムチ400g',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5971879604,
#   'user_id': 8264209,
#   'date': '2022-06-04',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 128,
#   'comment': '',
#   'active': 1,
#   'created': '2022-06-04 14:49:12',
#   'currency_code': 'JPY',
#   'name': 'スパゲッティ1.6mm',
#   'receipt_id': 1654321743,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962032885,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 22,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:37:20',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1653971806,
#   'place_uid': 'zm-8468381ef0f654d9',
#   'place': '生鮮館和光府中店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962032846,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 190,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:37:19',
#   'currency_code': 'JPY',
#   'name': '千物バラ',
#   'receipt_id': 1653971806,
#   'place_uid': 'zm-8468381ef0f654d9',
#   'place': '生鮮館和光府中店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962032806,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 95,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:37:18',
#   'currency_code': 'JPY',
#   'name': '肉厚生椎茸',
#   'receipt_id': 1653971806,
#   'place_uid': 'zm-8468381ef0f654d9',
#   'place': '生鮮館和光府中店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962031278,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 23,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:36:38',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1653971754,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5962031219,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 14850256,
#   'to_account_id': 0,
#   'amount': 299,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:36:37',
#   'currency_code': 'JPY',
#   'name': 'ジャガイモ',
#   'receipt_id': 1653971754,
#   'place_uid': 'zm-d4a6725122addbb1',
#   'place': 'ロピア',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '現金',
#   'to': '-'},
#  {'id': 5962030102,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 93,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:56',
#   'currency_code': 'JPY',
#   'name': '外税',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962030053,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 20,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:54',
#   'currency_code': 'JPY',
#   'name': '1食焼きそば',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962030019,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 69,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:53',
#   'currency_code': 'JPY',
#   'name': '秀月ちくわ',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962029998,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 298,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:52',
#   'currency_code': 'JPY',
#   'name': 'ミートボール',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962029975,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 278,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:51',
#   'currency_code': 'JPY',
#   'name': '冷凍ポテト',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962029952,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 188,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:50',
#   'currency_code': 'JPY',
#   'name': 'むき枝豆',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962029921,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 72,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:49',
#   'currency_code': 'JPY',
#   'name': 'ホールトマト缶詰',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  {'id': 5962029887,
#   'user_id': 8264209,
#   'date': '2022-05-31',
#   'mode': 'payment',
#   'category_id': 101,
#   'genre_id': 10101,
#   'from_account_id': 0,
#   'to_account_id': 0,
#   'amount': 147,
#   'comment': '',
#   'active': 1,
#   'created': '2022-05-31 13:35:48',
#   'currency_code': 'JPY',
#   'name': '神戸物産つゆの素',
#   'receipt_id': 1653971737,
#   'place_uid': 'yh-Ai_fMuWFfjw',
#   'place': '業務スーパー\u3000リカーキング府中本宿店',
#   'category': '食費',
#   'genre': '食料品',
#   'from': '-',
#   'to': '-'},
#  ...]
